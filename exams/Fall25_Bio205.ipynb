# %%
# importing the required module
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import gaussian_kde
from statistics import mean, stdev
from scipy.stats import sem
import scipy.stats as stats
from scipy.stats import gaussian_kde

# %%
#Optional for disabling warnings
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
df = pd.read_csv (r'./70865exam1.csv', index_col=0)
df.describe()
# Out:
#                   ID   SIS User ID  \
# count      71.000000  7.000000e+01
# mean   191866.577465  9.003058e+08
# std     72677.670165  8.250854e+04
# min      8612.000000  9.000039e+08
# 25%    187560.000000  9.002939e+08
# 50%    212145.000000  9.003286e+08
# 75%    240369.500000  9.003570e+08
# max    254486.000000  9.003703e+08
#
#        Mandatory - Course Contract Agreement (885735)  \
# count                                            71.0
# mean                                              1.0
# std                                               0.0
# min                                               1.0
# 25%                                               1.0
# 50%                                               1.0
# 75%                                               1.0
# max                                               1.0
#
#        Exercise: Introduce Yourself (885706)  Photo Final Exam (885697)  \
# count                              70.000000                        1.0
# mean                                1.978571                       50.0
# std                                 0.101999                        NaN
# min                                 1.500000                       50.0
# 25%                                 2.000000                       50.0
# 50%                                 2.000000                       50.0
# 75%                                 2.000000                       50.0
# max                                 2.000000                       50.0
#
#        Lecture Exam 1 (885731)  Lecture Exam 2 (885732)  \
# count                68.000000                      1.0
# mean                 76.279412                    100.0
# std                  16.993278                      NaN
# min                   0.000000                    100.0
# 25%                  66.000000                    100.0
# 50%                  79.500000                    100.0
# 75%                  88.250000                    100.0
# max                 100.000000                    100.0
#
#        Lecture Exam 3 (885733)  Lecture Exam 4 (885734)  \
# count                      1.0                      1.0
# mean                     100.0                    100.0
# std                        NaN                      NaN
# min                      100.0                    100.0
# 25%                      100.0                    100.0
# 50%                      100.0                    100.0
# 75%                      100.0                    100.0
# max                      100.0                    100.0
#
#        EC #1 - Anatomy of the human brain (885707)  ...  \
# count                                          1.0  ...
# mean                                           0.0  ...
# std                                            NaN  ...
# min                                            0.0  ...
# 25%                                            0.0  ...
# 50%                                            0.0  ...
# 75%                                            0.0  ...
# max                                            0.0  ...
#
#        Lab10_Exam_online_Urinary and Reproductive Systems (885691)  \
# count                                                1.0
# mean                                                20.0
# std                                                  NaN
# min                                                 20.0
# 25%                                                 20.0
# 50%                                                 20.0
# 75%                                                 20.0
# max                                                 20.0
#
#        Lab Oral Exam 2 (885723)  Lab Oral Exam 3 (885724)  \
# count                 66.000000                 59.000000
# mean                   8.443182                 25.559322
# std                    1.127280                  5.315953
# min                    4.000000                  6.500000
# 25%                    8.500000                 23.000000
# 50%                    9.000000                 28.500000
# 75%                    9.000000                 29.500000
# max                    9.000000                 30.000000
#
#        Lab Oral Exam 4 (885725)  Lab Oral Exam 5 (885726)  \
# count                       1.0                       1.0
# mean                       18.0                      19.0
# std                         NaN                       NaN
# min                        18.0                      19.0
# 25%                        18.0                      19.0
# 50%                        18.0                      19.0
# 75%                        18.0                      19.0
# max                        18.0                      19.0
#
#        Lab Oral Exam 6 (885727)  Lab Oral Exam 7 (885728)  \
# count                       1.0                       1.0
# mean                       12.0                      16.0
# std                         NaN                       NaN
# min                        12.0                      16.0
# 25%                        12.0                      16.0
# 50%                        12.0                      16.0
# 75%                        12.0                      16.0
# max                        12.0                      16.0
#
#        Lab Oral Exam 8 (885729)  Lab Oral Exam 9 (885730)  \
# count                       1.0                       1.0
# mean                       10.0                      12.0
# std                         NaN                       NaN
# min                        10.0                      12.0
# 25%                        10.0                      12.0
# 50%                        10.0                      12.0
# 75%                        10.0                      12.0
# max                        10.0                      12.0
#
#        Lab Oral Exam 10 (885722)
# count                        1.0
# mean                        15.0
# std                          NaN
# min                         15.0
# 25%                         15.0
# 50%                         15.0
# 75%                         15.0
# max                         15.0
#
# [8 rows x 41 columns]

# %%
# Plot Histogram on x
x1 = df['Lecture Exam 1 (885731)'].dropna()
x1 = x1[x1 != 0]

# Define number of bins for the histogram
bins = 25

# Plot histogram with actual frequency (density=False)
count_x1, bins_x1, _ = plt.hist(x1, bins=bins, edgecolor='k', alpha=0.6, density=False)
plt.gca().set(title='Frequency Distribution - 70865 - Lecture Exam 1 ', ylabel='Frequency')
plt.xlim(0, 100)

# Add KDE c ve
kde_x1 = gaussian_kde(x1)
x1_range = np.linspace(0, 100, 1000)  # Generate x-values for KDE curve

# Scale KDE by the number of data points and the bin width to match the histogram's frequency scale
bin_width_x1 = bins_x1[1] - bins_x1[0]
plt.plot(x1_range, kde_x1(x1_range) * len(x1) * bin_width_x1, color='r', linewidth=2)

# Plot vertical line for mean
plt.axvline(x1.mean(), color='k', linestyle='dashed', linewidth=1)

# Add mean text
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*0.7, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()))

# Display the plot
plt.show()

# %%
df2 = pd.read_csv (r'./70868exam1.csv', index_col=0)
df2.describe()
# Out:
#                   ID   SIS User ID  \
# count      50.000000  5.000000e+01
# mean   172583.780000  9.003046e+08
# std     88045.172008  5.954900e+04
# min      8205.000000  9.000885e+08
# 25%    158127.000000  9.002708e+08
# 50%    209714.000000  9.003279e+08
# 75%    233549.750000  9.003481e+08
# max    253818.000000  9.003703e+08
#
#        Mandatory - Course Contract Agreement (885695)  \
# count                                       51.000000
# mean                                         0.980392
# std                                          0.140028
# min                                          0.000000
# 25%                                          1.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          1.000000
#
#        Exercise: Introduce Yourself (885664)  Photo Final Exam (885658)  \
# count                              51.000000                        1.0
# mean                                1.941176                       50.0
# std                                 0.294059                        NaN
# min                                 0.000000                       50.0
# 25%                                 2.000000                       50.0
# 50%                                 2.000000                       50.0
# 75%                                 2.000000                       50.0
# max                                 2.000000                       50.0
#
#        Lecture Exam 1 (885690)  Lecture Exam 2 (885692)  \
# count                49.000000                      1.0
# mean                 68.142857                    100.0
# std                  22.291628                      NaN
# min                   0.000000                    100.0
# 25%                  49.000000                    100.0
# 50%                  73.000000                    100.0
# 75%                  85.000000                    100.0
# max                 100.000000                    100.0
#
#        Lecture Exam 3 (885693)  Lecture Exam 4 (885694)  \
# count                      1.0                      1.0
# mean                     100.0                    100.0
# std                        NaN                      NaN
# min                      100.0                    100.0
# 25%                      100.0                    100.0
# 50%                      100.0                    100.0
# 75%                      100.0                    100.0
# max                      100.0                    100.0
#
#        EC #1 - Anatomy of the human brain (885665)  ...  \
# count                                          1.0  ...
# mean                                           0.0  ...
# std                                            NaN  ...
# min                                            0.0  ...
# 25%                                            0.0  ...
# 50%                                            0.0  ...
# 75%                                            0.0  ...
# max                                            0.0  ...
#
#        Lab10_Exam_online_Urinary and Reproductive Systems (885661)  \
# count                                                1.0
# mean                                                20.0
# std                                                  NaN
# min                                                 20.0
# 25%                                                 20.0
# 50%                                                 20.0
# 75%                                                 20.0
# max                                                 20.0
#
#        Lab Oral Exam 2 (885681)  Lab Oral Exam 3 (885682)  \
# count                 51.000000                 44.000000
# mean                   7.529412                 25.375000
# std                    2.635169                  5.954405
# min                    0.000000                  7.000000
# 25%                    7.500000                 24.000000
# 50%                    8.500000                 27.500000
# 75%                    9.000000                 30.000000
# max                    9.000000                 30.000000
#
#        Lab Oral Exam 4 (885683)  Lab Oral Exam 5 (885684)  \
# count                       1.0                       1.0
# mean                       18.0                      19.0
# std                         NaN                       NaN
# min                        18.0                      19.0
# 25%                        18.0                      19.0
# 50%                        18.0                      19.0
# 75%                        18.0                      19.0
# max                        18.0                      19.0
#
#        Lab Oral Exam 6 (885685)  Lab Oral Exam 7 (885686)  \
# count                       1.0                       1.0
# mean                       12.0                      16.0
# std                         NaN                       NaN
# min                        12.0                      16.0
# 25%                        12.0                      16.0
# 50%                        12.0                      16.0
# 75%                        12.0                      16.0
# max                        12.0                      16.0
#
#        Lab Oral Exam 8 (885687)  Lab Oral Exam 9 (885688)  \
# count                       1.0                       1.0
# mean                       10.0                      12.0
# std                         NaN                       NaN
# min                        10.0                      12.0
# 25%                        10.0                      12.0
# 50%                        10.0                      12.0
# 75%                        10.0                      12.0
# max                        10.0                      12.0
#
#        Lab Oral Exam 10 (885680)
# count                        1.0
# mean                        15.0
# std                          NaN
# min                         15.0
# 25%                         15.0
# 50%                         15.0
# 75%                         15.0
# max                         15.0
#
# [8 rows x 41 columns]

# %%
# Plot Histogram on x
x2 = df2['Lecture Exam 1 (885690)'].dropna()
x2 = x2[x2 != 0]

# Define number of bins for the histogram
bins = 25

# Plot histogram with actual frequency (density=False)
count_x2, bins_x2, _ = plt.hist(x2, bins=bins, edgecolor='k', alpha=0.6, density=False)
plt.gca().set(title='Frequency Distribution - 70868 - Lecture Exam 1 ', ylabel='Frequency')
plt.xlim(0, 100)

# Add KDE c ve
kde_x2 = gaussian_kde(x2)
x2_range = np.linspace(0, 100, 1000)  # Generate x-values for KDE curve

# Scale KDE by the number of data points and the bin width to match the histogram's frequency scale
bin_width_x2 = bins_x2[1] - bins_x2[0]
plt.plot(x2_range, kde_x2(x2_range) * len(x2) * bin_width_x2, color='r', linewidth=2)

# Plot vertical line for mean
plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)

# Add mean text
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*0.7, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))

# Display the plot
plt.show()

# %%
# make x1 x3
x3 = x1

# %%
bins = np.linspace(0, 100, 8)
plt.figure(figsize=(10, 7), dpi=300)

# Histograms (density)
plt.hist(x2, bins=bins, density=True, alpha=0.4, edgecolor='k', label="NCC (70868)", color="dodgerblue")
plt.hist(x3, bins=bins, density=True, alpha=0.4, edgecolor='k', label="SLO (70865)", color="orange")

# KDE on density scale
x_grid = np.linspace(0, 100, 1000)
kde2 = gaussian_kde(x2)
kde3 = gaussian_kde(x3)
plt.plot(x_grid, kde2(x_grid), linewidth=3)
plt.plot(x_grid, kde3(x_grid), linewidth=3)

plt.axvline(x2.mean(), linestyle='dashed', linewidth=1, color="dodgerblue")
plt.axvline(x3.mean(), linestyle='dashed', linewidth=1, color="orange")

# Add text labels for means
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean() * .8525, max_ylim * 0.965, 'Mean: {:.2f}'.format(x2.mean()), color="dodgerblue")
plt.text(x3.mean() * 1.005, max_ylim * 0.965, 'Mean: {:.2f}'.format(x3.mean()), color="orange")

plt.xlim(0, 100)
plt.legend()
plt.title('Fall 2025 Human Anatomy - Lecture Exam 1')
plt.xlabel('Score (%)')
plt.ylabel('Density')
plt.tight_layout()
plt.show()
